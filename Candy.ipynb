# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel('C:/Users/Taha/Downloads/candyhierarchy2017.xlsx')
data.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
#to know information about data and missing values (if it exist)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %%
#to know sum of missing values
data.isnull().sum()
# Out:
# Internal ID                    0
# Q1: GOING OUT?               110
# Q2: GENDER                    41
# Q3: AGE                       84
# Q4: COUNTRY                   64
#                             ...
# Q12: MEDIA [Daily Dish]     2375
# Q12: MEDIA [Science]        1098
# Q12: MEDIA [ESPN]           2361
# Q12: MEDIA [Yahoo]          2393
# Click Coordinates (x, y)     855
# Length: 120, dtype: int64

# %%
#to drop columns which unuseful
data.drop(['Q12: MEDIA [Yahoo]','Q12: MEDIA [ESPN]','Q12: MEDIA [Daily Dish]','Unnamed: 113','Q11: DAY' , 'Q8: DESPAIR OTHER','Q9: OTHER COMMENTS'],axis=1,inplace=True)
data.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
#set data index by'Internal ID' columns to make drop all rows has a nan values in all colmuns be easy
data.set_index('Internal ID',inplace=True)

# %%
#drop drop all rows has a nan values in all colmuns
data.dropna(how='all',inplace=True)
data.head()
# Out:
#             Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# Internal ID
# 90272821                No       Male      44        USA
# 90272829               NaN       Male      49         USA
# 90272840                No       Male      40          us
# 90272841                No       Male      23         usa
# 90272852                No       Male     NaN         NaN
#
#             Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# Internal ID
# 90272821                                  NM                MEH
# 90272829                            Virginia                NaN
# 90272840                                  or                MEH
# 90272841                            exton pa                JOY
# 90272852                                 NaN                JOY
#
#             Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# ...

# %%
#strip columns name
for col in data.columns:
    data=data.rename(columns=lambda x: x.strip('Q : | 0123456789 ? '))
data.head()
# Out:
#             GOING OUT GENDER  AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male   44    USA                            NM
# 90272829          NaN   Male   49     USA                     Virginia
# 90272840           No   Male   40      us                           or
# 90272841           No   Male   23     usa                     exton pa
# 90272852           No   Male  NaN     NaN                          NaN
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2439 entries, 90272821 to 90314802
# Columns: 112 entries, GOING OUT to Click Coordinates (x, y)
# dtypes: float64(1), object(111)
# memory usage: 2.1+ MB

# %%
#dtype of columns
data.dtypes
# Out:
# GOING OUT                        object
# GENDER                           object
# AGE                              object
# COUNTRY                          object
# STATE, PROVINCE, COUNTY, ETC     object
#                                  ...
# York Peppermint Patties          object
# JOY OTHER                        object
# DRESS                            object
# MEDIA [Science]                 float64
# Click Coordinates (x, y)         object
# Length: 112, dtype: object

# %%
data.isnull().sum()
# Out:
# GOING OUT                         89
# GENDER                            20
# AGE                               63
# COUNTRY                           43
# STATE, PROVINCE, COUNTY, ETC      79
#                                 ...
# York Peppermint Patties          684
# JOY OTHER                       1528
# DRESS                            723
# MEDIA [Science]                 1077
# Click Coordinates (x, y)         834
# Length: 112, dtype: int64

# %%
#convert dtype if 'AGE' column to be numeric to fill nan by statistical methods
data['AGE'] = data['AGE'].apply(pd.to_numeric, downcast='float', errors='coerce')

# %%
#distplot 'AGE' to know if it normal distriburion of skewed and select if we fillna by mean of median
plt.figure(figsize=(10,10))
plt.xlim(0,100)
sns.distplot(data['AGE'])

# %%
#normal distribution so mean and median are same
#median of columns['AGE','MEDIA [Science]']
dfmedian=data[['AGE','MEDIA [Science]']].median()

# %%
#fill nan values with median value
data[['AGE','MEDIA [Science]']]=data[['AGE','MEDIA [Science]']].fillna(dfmedian)
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829          NaN   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     NaN                          NaN
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
#in object columns we fillna with the most freq
data['DRESS'].value_counts()
# Out:
# White and gold    1081
# Blue and black     635
# Name: DRESS, dtype: int64

# %%
data['DRESS']=data[['DRESS']].fillna('White and gold')
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829          NaN   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     NaN                          NaN
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
data['COUNTRY'].value_counts()
# Out:
# USA                699
# United States      497
# usa                217
# Canada             179
# Usa                139
#                   ...
# North Carolina       1
# United kingdom       1
# The Netherlands      1
# Iceland              1
# Canada`              1
# Name: COUNTRY, Length: 128, dtype: int64

# %%
data['COUNTRY']=data['COUNTRY'].fillna('USA')
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829          NaN   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     USA                          NaN
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
data['GENDER'].value_counts()
# Out:
# Male                  1467
# Female                 839
# I'd rather not say      83
# Other                   30
# Name: GENDER, dtype: int64

# %%
data['GENDER']=data[['GENDER']].fillna('Male')
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829          NaN   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     USA                          NaN
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
data['GOING OUT'].value_counts()
# Out:
# No     2038
# Yes     312
# Name: GOING OUT, dtype: int64

# %%
data['GOING OUT']=data[['GOING OUT']].fillna('No')
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829           No   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     USA                          NaN
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
data['STATE, PROVINCE, COUNTY, ETC'].value_counts()
# Out:
# California    132
# CA             89
# Texas          60
# Ontario        56
# Illinois       55
#              ...
# DC              1
# Greifswald      1
# Va              1
# nh              1
# Sub Earth       1
# Name: STATE, PROVINCE, COUNTY, ETC, Length: 511, dtype: int64

# %%
data['STATE, PROVINCE, COUNTY, ETC']=data[['STATE, PROVINCE, COUNTY, ETC']].fillna('California')
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829           No   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     USA                   California
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
data['Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)'].value_counts()
# Out:
# DESPAIR    1089
# MEH         461
# JOY         176
# Name: Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes), dtype: int64

# %%
data['Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)']=data[['Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)']].fillna('DWSPAIR')
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829           No   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     USA                   California
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                               DWSPAIR
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
#another easier way .. use lambda function to get the most freq values and fillna columns with this by for loop
for col in data.columns :
    col=lambda x: x.value_counts()
data.fillna(col)
data.head()
# Out:
#             GOING OUT GENDER   AGE COUNTRY STATE, PROVINCE, COUNTY, ETC  \
# Internal ID
# 90272821           No   Male  44.0    USA                            NM
# 90272829           No   Male  49.0     USA                     Virginia
# 90272840           No   Male  40.0      us                           or
# 90272841           No   Male  23.0     usa                     exton pa
# 90272852           No   Male  41.0     USA                   California
#
#             Grand Bar  \
# Internal ID
# 90272821          MEH
# 90272829          NaN
# 90272840          MEH
# 90272841          JOY
# 90272852          JOY
#
#             Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90272821                                               DESPAIR
# 90272829                                               DWSPAIR
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
# ...

# %%
#check if there are mising values 
data.isnull().sum()
# Out:
# GOING OUT                          0
# GENDER                             0
# AGE                                0
# COUNTRY                            0
# STATE, PROVINCE, COUNTY, ETC       0
#                                 ...
# York Peppermint Patties          684
# JOY OTHER                       1528
# DRESS                              0
# MEDIA [Science]                    0
# Click Coordinates (x, y)         834
# Length: 112, dtype: int64

# %%
#plot feeling about cabdy corn  at different ages
sns.barplot(x=data['Candy Corn'] ,y=data['AGE'] )
plt.xlabel('Feelings')

plt.show()

# %%
#plot feeling about white bread at different gender

plt.figure(figsize=(12,10))
sns.countplot(x='White Bread' , data=data , hue='GENDER',palette ='Set1')
plt.show()
